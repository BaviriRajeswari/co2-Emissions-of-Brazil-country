# %% [markdown]
# CO2 EMMISIONS

# %%
#Import all the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#First read the Dataset with the help of pandas read csv

# %%
df=pd.read_csv("/content/dates.csv")
df
# Out:
#     country        date sector     value   timestamp
# 0    Brazil  01-01-2019  Power  0.096799  1546300800
# 1    Brazil  02-01-2019  Power  0.116758  1546387200
# 2    Brazil  03-01-2019  Power  0.113519  1546473600
# 3    Brazil  04-01-2019  Power  0.102161  1546560000
# 4    Brazil  05-01-2019  Power  0.109161  1546646400
# ..      ...         ...    ...       ...         ...
# 360  Brazil  27-12-2019  Power  0.261647  1577404800
# 361  Brazil  28-12-2019  Power  0.296558  1577491200
# 362  Brazil  29-12-2019  Power  0.306057  1577577600
# 363  Brazil  30-12-2019  Power  0.309332  1577664000
# 364  Brazil  31-12-2019  Power  0.300322  1577750400
#
# [365 rows x 5 columns]

# %%
#My dataset contains following columns
#1) Country 2) Sector 3) Value 4)timestamp 5)Date

# %%
#DATA CLEANING

# %% [markdown]
# Change the format of the date

# %%
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')

# %%
df
# Out:
#     country       date sector     value   timestamp
# 0    Brazil 2019-01-01  Power  0.096799  1546300800
# 1    Brazil 2019-01-02  Power  0.116758  1546387200
# 2    Brazil 2019-01-03  Power  0.113519  1546473600
# 3    Brazil 2019-01-04  Power  0.102161  1546560000
# 4    Brazil 2019-01-05  Power  0.109161  1546646400
# ..      ...        ...    ...       ...         ...
# 360  Brazil 2019-12-27  Power  0.261647  1577404800
# 361  Brazil 2019-12-28  Power  0.296558  1577491200
# 362  Brazil 2019-12-29  Power  0.306057  1577577600
# 363  Brazil 2019-12-30  Power  0.309332  1577664000
# 364  Brazil 2019-12-31  Power  0.300322  1577750400
#
# [365 rows x 5 columns]

# %%
#Date changed to the format

# %%
#Get the information of my dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    365 non-null    object
#  1   date       365 non-null    datetime64[ns]
#  2   sector     365 non-null    object
#  3   value      365 non-null    float64
#  4   timestamp  365 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 14.4+ KB

# %%
#Check the null values

# %%
df.isnull().sum()
# Out:
# country      0
# date         0
# sector       0
# value        0
# timestamp    0
# dtype: int64

# %%
df.value_counts()
# Out:
# country  date        sector  value     timestamp
# Brazil   2019-01-01  Power   0.096799  1546300800    1
#          2019-09-09  Power   0.278325  1567987200    1
#          2019-09-07  Power   0.270081  1567814400    1
#          2019-09-06  Power   0.301641  1567728000    1
#          2019-09-05  Power   0.287320  1567641600    1
#                                                     ..
#          2019-05-01  Power   0.146437  1556668800    1
#          2019-04-30  Power   0.186423  1556582400    1
#          2019-04-29  Power   0.179723  1556496000    1
#          2019-04-28  Power   0.148127  1556409600    1
#          2019-12-31  Power   0.300322  1577750400    1
# Length: 365, dtype: int64

# %%
df['date'].value_counts()
# Out:
# 2019-01-01    1
# 2019-09-09    1
# 2019-09-07    1
# 2019-09-06    1
# 2019-09-05    1
#              ..
# 2019-05-01    1
# 2019-04-30    1
# 2019-04-29    1
# 2019-04-28    1
# 2019-12-31    1
# Name: date, Length: 365, dtype: int64

# %%
# My dataset contains the 2019 date and the changes in days of the month

# %% [markdown]
# Using describe function to get the count,mean,min and std of the dataset

# %%
df.describe()
# Out:
#             value     timestamp
# count  365.000000  3.650000e+02
# mean     0.219726  1.562026e+09
# std      0.070004  9.116121e+06
# min      0.079695  1.546301e+09
# 25%      0.153415  1.554163e+09
# 50%      0.229902  1.562026e+09
# 75%      0.282055  1.569888e+09
# max      0.335245  1.577750e+09

# %%
df.head()
# Out:
#   country       date sector     value   timestamp
# 0  Brazil 2019-01-01  Power  0.096799  1546300800
# 1  Brazil 2019-01-02  Power  0.116758  1546387200
# 2  Brazil 2019-01-03  Power  0.113519  1546473600
# 3  Brazil 2019-01-04  Power  0.102161  1546560000
# 4  Brazil 2019-01-05  Power  0.109161  1546646400

# %%
df.tail()
# Out:
#     country       date sector     value   timestamp
# 360  Brazil 2019-12-27  Power  0.261647  1577404800
# 361  Brazil 2019-12-28  Power  0.296558  1577491200
# 362  Brazil 2019-12-29  Power  0.306057  1577577600
# 363  Brazil 2019-12-30  Power  0.309332  1577664000
# 364  Brazil 2019-12-31  Power  0.300322  1577750400

# %%
# Aggregate total CO2 emissions by country
# Plot total CO2 emissions by country
total_emissions_by_country = df.groupby('country')['value'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
total_emissions_by_country.plot(kind='bar', color='steelblue')
plt.title('Total CO2 Emissions by Country')
plt.xlabel('Country')
plt.ylabel('Total CO2 Emissions')
plt.show()

# %%
#Brazil contains 80 co2 emissions with the value

# %%
# Aggregate total CO2 emissions by sector
# Plot total CO2 emissions by sector
total_emissions_by_sector = df.groupby('sector')['value'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
total_emissions_by_sector.plot(kind='bar', color='steelblue')
plt.title('Total CO2 Emissions by Sector')
plt.xlabel('Sector')
plt.ylabel('Total CO2 Emissions')
plt.show()

# %%
# Convert 'date' column to datetime
# Create a 'day' column for easy daily aggregation
# Show the first few rows of the DataFrame to confirm changes


df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df['day'] = df['date'].dt.day

# %%
df.head()
# Out:
#   country       date sector     value   timestamp  day
# 0  Brazil 2019-01-01  Power  0.096799  1546300800    1
# 1  Brazil 2019-01-02  Power  0.116758  1546387200    2
# 2  Brazil 2019-01-03  Power  0.113519  1546473600    3
# 3  Brazil 2019-01-04  Power  0.102161  1546560000    4
# 4  Brazil 2019-01-05  Power  0.109161  1546646400    5

# %%
# Aggregate total CO2 emissions by days
# Plot total CO2 emissions by days
total_emissions_by_year = df.groupby('day')['value'].sum()
plt.figure(figsize=(10, 6))
total_emissions_by_year.plot(kind='line', marker='o', color='steelblue')
plt.title('Total CO2 Emissions by day')
plt.xlabel('day')
plt.ylabel('Total CO2 Emissions')
plt.xticks(total_emissions_by_year.index)
plt.grid(True)
plt.show()

# %% [markdown]
# #Here is the day by day co2 emission in brazil country in 2019 year.

# %%
unique_sectors = df['sector'].unique()

# %%
# Aggregate total CO2 emissions by year, sector, and country for the brazil
# Plot total CO2 emissions by year for each sector in the brazil
total_emissions_by_year_sector_us = df[df['country'] == 'Brazil'].groupby(['day', 'sector'])['value'].sum().unstack()
plt.figure(figsize=(12, 8))
for sector in unique_sectors:
    plt.plot(total_emissions_by_year_sector_us.index, total_emissions_by_year_sector_us[sector], marker='o', label=sector)
plt.title('Total CO2 Emissions by Year and Sector for the Brazil')
plt.xlabel('day')
plt.ylabel('Total CO2 Emissions')
plt.xticks(total_emissions_by_year_sector_us.index)
plt.legend(title='Sector')
plt.grid(True)
plt.show()

# %%
#Here is the power is the only sector of co2 emission in brazil by year.

# %%
# we can identify the day of 18 it emits the more amount of co2

# %%
#Draw a plot to identify the difference

# %%
df.plot(x='date', y='value')
plt.show()

# %%
# It was a seasonal difference

# %%
# Testing For Stationarity

from statsmodels.tsa.stattools import adfuller

# %%
#Take the value column
test_result=adfuller(df['value'])

# %% [markdown]
# Checking for the stationary of the dataset that is adfuller test and the value of p is greater than the 1 like 0.05 then the dataset is stationary and strong null hypothesis otherwise it is non stationary and a weak hypothesis.

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(value):
    result=adfuller(value)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['value'])
# Out:
# ADF Test Statistic : -1.475763600192832
# p-value : 0.5454648648233055
# #Lags Used : 15
# Number of Observations Used : 349
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %% [markdown]
# #Here my datasets p value is 0.54 is not greater than one so it is non-stationary

# %%
#The given data was not in stationary so need to put in stationary now i have to do differencing of the value column.

# %% [markdown]
# DIFFERENCING

# %%
df['value First Difference'] = df['value'] - df['value'].shift(1)
df['value'].shift(1)
# Out:
# 0           NaN
# 1      0.096799
# 2      0.116758
# 3      0.113519
# 4      0.102161
#          ...
# 360    0.249963
# 361    0.261647
# 362    0.296558
# 363    0.306057
# 364    0.309332
# Name: value, Length: 365, dtype: float64

# %% [markdown]
# Seasonal Difference

# %%
df['Seasonal First Difference']=df['value']-df['value'].shift(30)

# %%
# Here the value First Difference and  seasonal First Difference are added to the data.

# %%
df.head(24)
# Out:
#    country       date sector     value   timestamp  day  \
# 0   Brazil 2019-01-01  Power  0.096799  1546300800    1
# 1   Brazil 2019-01-02  Power  0.116758  1546387200    2
# 2   Brazil 2019-01-03  Power  0.113519  1546473600    3
# 3   Brazil 2019-01-04  Power  0.102161  1546560000    4
# 4   Brazil 2019-01-05  Power  0.109161  1546646400    5
# 5   Brazil 2019-01-06  Power  0.111300  1546732800    6
# 6   Brazil 2019-01-07  Power  0.101731  1546819200    7
# 7   Brazil 2019-01-08  Power  0.105307  1546905600    8
# 8   Brazil 2019-01-09  Power  0.108397  1546992000    9
# 9   Brazil 2019-01-10  Power  0.109340  1547078400   10
# 10  Brazil 2019-01-11  Power  0.107051  1547164800   11
# 11  Brazil 2019-01-12  Power  0.121771  1547251200   12
# 12  Brazil 2019-01-13  Power  0.096518  1547337600   13
# 13  Brazil 2019-01-14  Power  0.145747  1547424000   14
# 14  Brazil 2019-01-15  Power  0.147708  1547510400   15
# 15  Brazil 2019-01-16  Power  0.169617  1547596800   16
# ...

# %%
#This dataset was not in stationary so, checking for the stationary again with value difference and seasonal difference.

# %%
adfuller_test(df['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -3.3889951923097623
# p-value : 0.011339794586569016
# #Lags Used : 15
# Number of Observations Used : 319
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %% [markdown]
# #The data has in stationary

# %%
df['Seasonal First Difference'].plot()
# Out:
# <Axes: >

# %% [markdown]
# #the value of the country is changed in seasonal

# %% [markdown]
# Auto Regressive Model

# %%
#Importing sarima,acf and pacf models

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# %%
import statsmodels.api as sm

# %%
#For an autocorrelation model, the theoretical PACF “shuts off” past the order of the model. The phrase “shuts off” means that in theory the partial autocorrelations are equal to 0 beyond that point.
#Partial autocorrelation model is a useful tool in time series analysis for understanding the relationship between an observation and its lag, accounting for the intermediate lags. The PACF at lag k is the correlation between the series and its own values, lagged by k time units, with the influence of the values at intermediate lags removed.

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Seasonal First Difference'].iloc[31:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Seasonal First Difference'].iloc[31:],lags=40,ax=ax2)

# %%
# Replace P, D, and Q with the chosen values
order = (4,1,2)
seasonal_order = (1,1,1,30)

# %%
#Fitting the MODEL

# %%
model = SARIMAX(df['value'], order=(4,1,2),seasonal_order=(1,1,1,30))
result = model.fit(disp=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %% [markdown]
# Add the result predict with the future dateoffset

# %%
from pandas.tseries.offsets import DateOffset

# %%
#fix the future dataset with in range of 5 months
future_dates = [df.iloc[-1]["date"] + DateOffset(months = x) for x in range (0,5)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            country date sector value timestamp  day value First Difference  \
# 2020-01-31     NaN  NaN    NaN   NaN       NaN  NaN                    NaN
# 2020-02-29     NaN  NaN    NaN   NaN       NaN  NaN                    NaN
# 2020-03-31     NaN  NaN    NaN   NaN       NaN  NaN                    NaN
# 2020-04-30     NaN  NaN    NaN   NaN       NaN  NaN                    NaN
#
#            Seasonal First Difference
# 2020-01-31                       NaN
# 2020-02-29                       NaN
# 2020-03-31                       NaN
# 2020-04-30                       NaN

# %%
# Here is the future predict forecasting in the year of 2020
#concat the data with future dates

# %%
future_df=pd.concat([df,future_datest_df])

# %%
#plot between value and future forecasting

# %%
future_df['forecast'] = result.predict(start = 330, end =460, dynamic= True)
future_df[['value', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
CONCLUSION
#Our carbon dioxide (CO2) emissions dataset is one of our most-used datasets on Our World in Data.
#It is the key metric we need to understand our progress on slowing global climate change.
#Brazil country emitted 80% of CO2 in 2019, and global emissions in 2019 were 36 billion tonnes.
#The sector column has the 'power' situation can be emitted.
#The "timestamp" column in the dataset appears to represent the Unix timestamp,which is a way to represent time as the number of seconds that have elapsed since January 1, 1970 (the Unix epoch) at 00:00:00 UTC. This is a common format used in computing for representing time.
#Timestamp records the time amount of the emission.
#The "value" column in the dataset represents the numerical measurement associated with the "Power" sector on a given date.
#The "value" column provides a quantitative measure of the power associated with the "Power" sector. This measurement can represent energy consumption, production, or some other relevant metric.
 #we can identify the day of 18 it emits the more amount of co2.
